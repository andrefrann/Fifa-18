# %%
import pandas as pd
import os
data = pd.read_csv("PlayerPersonalData.csv")

# %%
data
# Out:
#        Unnamed: 0  Unnamed: 0.1      ID               Name  Age  \
# 0               0             0   20801  Cristiano Ronaldo   32
# 1               1             1  158023           L. Messi   30
# 2               2             2  190871             Neymar   25
# 3               3             3  176580          L. Suárez   30
# 4               4             4  167495           M. Neuer   31
# 5               5             5  188545     R. Lewandowski   28
# 6               6             6  193080             De Gea   26
# 7               7             7  183277          E. Hazard   26
# 8               8             8  182521           T. Kroos   27
# 9               9             9  167664         G. Higuaín   29
# 10             10            10  155862       Sergio Ramos   31
# 11             11            11  192985       K. De Bruyne   26
# 12             12            12  192119        T. Courtois   25
# 13             13            13  184941         A. Sánchez   28
# ...

# %%
data[(data.Overall >=75) & (data.Age <= 20)]
# Out:
#       Unnamed: 0  Unnamed: 0.1      ID              Name  Age  \
# 127          127           127  231747         K. Mbappé   18
# 128          128           128  231443        O. Dembélé   20
# 198          198           198  230621     G. Donnarumma   18
# 299          299           299  230666     Gabriel Jesus   20
# 302          302           302  222737            Malcom   20
# 392          392           392  231677       M. Rashford   19
# 394          394           394  216393      Y. Tielemans   20
# 520          520           520  230142         Oyarzabal   20
# 696          696           696  228687        K. Dolberg   19
# 698          698           698  227796        C. Pulisic   18
# 699          699           699  227234        L. Tousart   20
# 706          706           706  223033        Jorge Meré   20
# 709          709           709  222509     Dani Ceballos   20
# 843          843           843  227234        L. Tousart   20
# ...
