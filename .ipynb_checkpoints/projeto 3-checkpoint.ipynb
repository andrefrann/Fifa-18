# %%
# %matplotlib inline
from math import *
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

# %%
data = pd.read_csv('CompleteDataset.csv')
data = data.dropna()
data = data[pd.notnull(data.Value)]
# Out:
# C:\Users\andre\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Vm = []
Vk = []
V = []
for i in data.Value:
    if "M" in i:
        x = i.replace("€","")
        x = x.replace("M","")
        Vm.append(float(x))
            
    if "K" in i:
        x = i.replace("€","")
        x = x.replace("K","")        
        Vk.append(float(x))
        
for i in Vm:
    V.append(i*1000)
    
for i in Vk:
    V.append(i)

# %%
Valor = pd.Series(V)
data["Valor"] = Valor
data = data[pd.notnull(data.Valor)]

# %%
data.plot.scatter('Overall',"Valor");

# %%
data.plot.scatter('Potential','Valor');

# %%
data.plot.scatter('Overall','Potential');

# %%
Y = data['Valorlog']
X = data['Overall']
X = sm.add_constant(X)
model = sm.OLS(Y,X)
results = model.fit()
results.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-35f3147a9ab6> in <module>()
# ----> 1 Y = data['Valorlog']
#       2 X = data['Overall']
#       3 X = sm.add_constant(X)
#       4 model = sm.OLS(Y,X)
#       5 results = model.fit()
#
# NameError: name 'data' is not defined

# %%
a =673.5641
b = -4.327e+04

# %%
y = a*data.Potential + b
plt.plot(data.Potential,y)

# %%
excel = pd.DataFrame()
excel["Nome"] = data.Name
excel["Valor"] = data.Valor
excel["Overall"] = data.Overall
excel["Potencial"] = data.Potential
#excel.to_excel("fifa18.xlsx")
